# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
menstrual_data_path = "../Kaggle_Menstrual_Cycle_dataset.csv"
menstrual_df= pd.read_csv(menstrual_data_path)
menstrual_df.head()
print(menstrual_df.shape)
# Out:
# (1665, 80)

# %%
# printing out the unique values in each column
# for cols in menstrual_df.columns:
    # print(f"{cols} : \n {menstrual_df[cols].unique()} \n \n")

print(f"{menstrual_df['ClientID'].unique()} \n \n")
# Out:
# ['nfp8122' 'nfp8114' 'nfp8109' 'nfp8107' 'nfp8106' 'nfp8024' 'nfp8020'
#  'nfp8026' 'nfp8030' 'nfp8031' 'nfp8032' 'nfp8034' 'nfp8036' 'nfp8040'
#  'nfp8041' 'nfp8042' 'nfp8043' 'nfp8045' 'nfp8046' 'nfp8047' 'nfp8049'
#  'nfp8050' 'nfp8051' 'nfp8057' 'nfp8058' 'nfp8060' 'nfp8062' 'nfp8063'
#  'nfp8064' 'nfp8066' 'nfp8068' 'nfp8069' 'nfp8072' 'nfp8073' 'nfp8074'
#  'nfp8076' 'nfp8079' 'nfp8080' 'nfp8083' 'nfp8085' 'nfp8087' 'nfp8091'
#  'nfp8094' 'nfp8099' 'nfp8100' 'nfp8101' 'nfp8102' 'nfp8110' 'nfp8113'
#  'nfp8116' 'nfp8123' 'nfp8124' 'nfp8129' 'nfp8131' 'nfp8133' 'nfp8137'
#  'nfp8140' 'nfp8143' 'nfp8144' 'nfp8149' 'nfp8150' 'nfp8152' 'nfp8154'
#  'nfp8155' 'nfp8159' 'nfp8161' 'nfp8164' 'nfp8165' 'nfp8168' 'nfp8172'
#  'nfp8173' 'nfp8174' 'nfp8176' 'nfp8177' 'nfp8178' 'nfp8179' 'nfp8184'
#  'nfp8186' 'nfp8187' 'nfp8188' 'nfp8189' 'nfp8190' 'nfp8192' 'nfp8193'
#  'nfp8195' 'nfp8196' 'nfp8197' 'nfp8200' 'nfp8206' 'nfp8207' 'nfp8209'
#  'nfp8210' 'nfp8211' 'nfp8212' 'nfp8218' 'nfp8221' 'nfp8223' 'nfp8226'
#  'nfp8228' 'nfp8229' 'nfp8230' 'nfp8233' 'nfp8234' 'nfp8235' 'nfp8236'
#  'nfp8237' 'nfp8238' 'nfp8240' 'nfp8242' 'nfp8244' 'nfp8246' 'nfp8247'
#  'nfp8248' 'nfp8249' 'nfp8252' 'nfp8253' 'nfp8254' 'nfp8257' 'nfp8260'
#  'nfp8263' 'nfp8264' 'nfp8266' 'nfp8268' 'nfp8269' 'nfp8270' 'nfp8271'
#  'nfp8272' 'nfp8276' 'nfp8278' 'nfp8279' 'nfp8281' 'nfp8282' 'nfp8284'
#  'nfp8286' 'nfp8288' 'nfp8289' 'nfp8290' 'nfp8292' 'nfp8293' 'nfp8294'
#  'nfp8296' 'nfp8298' 'nfp8299' 'nfp8302' 'nfp8303' 'nfp8305' 'nfp8306'
#  'nfp8308' 'nfp8309' 'nfp8310' 'nfp8311' 'nfp8312' 'nfp8313' 'nfp8317'
#  'nfp8322' 'nfp8323' 'nfp8324' 'nfp8328' 'nfp8334']

# %%
# finding the unique client Ids
unique_client_ids = menstrual_df['ClientID'].unique()
print(f"Number of unique Client IDs: {len(unique_client_ids)}")
print(unique_client_ids)
# Out:
# Number of unique Client IDs: 159
# ['nfp8122' 'nfp8114' 'nfp8109' 'nfp8107' 'nfp8106' 'nfp8024' 'nfp8020'
#  'nfp8026' 'nfp8030' 'nfp8031' 'nfp8032' 'nfp8034' 'nfp8036' 'nfp8040'
#  'nfp8041' 'nfp8042' 'nfp8043' 'nfp8045' 'nfp8046' 'nfp8047' 'nfp8049'
#  'nfp8050' 'nfp8051' 'nfp8057' 'nfp8058' 'nfp8060' 'nfp8062' 'nfp8063'
#  'nfp8064' 'nfp8066' 'nfp8068' 'nfp8069' 'nfp8072' 'nfp8073' 'nfp8074'
#  'nfp8076' 'nfp8079' 'nfp8080' 'nfp8083' 'nfp8085' 'nfp8087' 'nfp8091'
#  'nfp8094' 'nfp8099' 'nfp8100' 'nfp8101' 'nfp8102' 'nfp8110' 'nfp8113'
#  'nfp8116' 'nfp8123' 'nfp8124' 'nfp8129' 'nfp8131' 'nfp8133' 'nfp8137'
#  'nfp8140' 'nfp8143' 'nfp8144' 'nfp8149' 'nfp8150' 'nfp8152' 'nfp8154'
#  'nfp8155' 'nfp8159' 'nfp8161' 'nfp8164' 'nfp8165' 'nfp8168' 'nfp8172'
#  'nfp8173' 'nfp8174' 'nfp8176' 'nfp8177' 'nfp8178' 'nfp8179' 'nfp8184'
#  'nfp8186' 'nfp8187' 'nfp8188' 'nfp8189' 'nfp8190' 'nfp8192' 'nfp8193'
#  'nfp8195' 'nfp8196' 'nfp8197' 'nfp8200' 'nfp8206' 'nfp8207' 'nfp8209'
#  'nfp8210' 'nfp8211' 'nfp8212' 'nfp8218' 'nfp8221' 'nfp8223' 'nfp8226'
#  'nfp8228' 'nfp8229' 'nfp8230' 'nfp8233' 'nfp8234' 'nfp8235' 'nfp8236'
#  'nfp8237' 'nfp8238' 'nfp8240' 'nfp8242' 'nfp8244' 'nfp8246' 'nfp8247'
#  'nfp8248' 'nfp8249' 'nfp8252' 'nfp8253' 'nfp8254' 'nfp8257' 'nfp8260'
#  'nfp8263' 'nfp8264' 'nfp8266' 'nfp8268' 'nfp8269' 'nfp8270' 'nfp8271'
#  'nfp8272' 'nfp8276' 'nfp8278' 'nfp8279' 'nfp8281' 'nfp8282' 'nfp8284'
#  'nfp8286' 'nfp8288' 'nfp8289' 'nfp8290' 'nfp8292' 'nfp8293' 'nfp8294'
#  'nfp8296' 'nfp8298' 'nfp8299' 'nfp8302' 'nfp8303' 'nfp8305' 'nfp8306'
#  'nfp8308' 'nfp8309' 'nfp8310' 'nfp8311' 'nfp8312' 'nfp8313' 'nfp8317'
#  'nfp8322' 'nfp8323' 'nfp8324' 'nfp8328' 'nfp8334']

# %%
# how many cycles do we have for each client
# Group by 'ClientID' and find the maximum 'CycleNumber' for each client
max_cycle_per_client = menstrual_df.groupby('ClientID')['CycleNumber'].max()

# Convert the result to a DataFrame
max_cycle_per_client_df = max_cycle_per_client.reset_index()

# Print the result
print(max_cycle_per_client_df)
# Out:
#     ClientID  CycleNumber
# 0    nfp8020           16
# 1    nfp8024           12
# 2    nfp8026            6
# 3    nfp8030           16
# 4    nfp8031           12
# ..       ...          ...
# 154  nfp8322           12
# 155  nfp8323           33
# 156  nfp8324           12
# 157  nfp8328           33
# 158  nfp8334           11
#
# [159 rows x 2 columns]

# %%
# Function to create the DataFrame for each column with cycle numbers, mean filling, and max cycle with all values
def create_cycle_df(df, column_name, cycle_column='CycleNumber'):
    # Convert the relevant column to numeric, coercing errors to NaN
    df[column_name] = pd.to_numeric(df[column_name], errors='coerce')

    # Group by 'ClientID' and aggregate the 'CycleNumber' and the target column
    grouped_df = df.groupby('ClientID').agg({
        cycle_column: list,
        column_name: list
    }).reset_index()

    # Find the maximum number of cycles any client has
    max_cycles = grouped_df[cycle_column].apply(len).max()

    # Initialize a new DataFrame to store cycle values in separate columns
    cycle_columns = [f'Cycle_{i+1}' for i in range(max_cycles)]
    cycle_values_df = pd.DataFrame(columns=['ClientID'] + cycle_columns + ['MaxCycleWithAllValues'])

    # Populate the DataFrame
    for idx, row in grouped_df.iterrows():
        client_id = row['ClientID']
        cycle_numbers = row[cycle_column]
        cycle_values = row[column_name]

        # Create a dictionary to store values for this client
        row_data = {'ClientID': client_id}

        # For each cycle number, assign the corresponding value
        for cycle_number, value in zip(cycle_numbers, cycle_values):
            row_data[f'Cycle_{cycle_number}'] = value

        for i in range(1, max_cycles + 1):
          if f'Cycle_{i}' not in row_data:
          # Calculate the mean of previous cycles
            previous_cycles = [row_data[f'Cycle_{j}'] for j in range(1, i) if f'Cycle_{j}' in row_data]
            if previous_cycles:
              row_data[f'Cycle_{i}'] = sum(previous_cycles) / len(previous_cycles)  # Fill with the mean
            else:
              row_data[f'Cycle_{i}'] = 28  # Default value if no previous cycles exist


        # Calculate the maximum cycle number where all cycles from Cycle_1 to Cycle_N have values
        max_cycle_with_all_values = 0
        for i in range(1, max_cycles + 1):
            if pd.notna(row_data.get(f'Cycle_{i}', None)):
                max_cycle_with_all_values = i
            else:
                break

        row_data['MaxCycleWithAllValues'] = max_cycle_with_all_values

        cycle_values_df = pd.concat([cycle_values_df, pd.DataFrame([row_data])], ignore_index=True)

    return cycle_values_df

# Create separate DataFrames for each column
length_of_cycle_df = create_cycle_df(menstrual_df, 'LengthofCycle')
estimated_ovulation_df = create_cycle_df(menstrual_df, 'EstimatedDayofOvulation')
luteal_phase_df = create_cycle_df(menstrual_df, 'LengthofLutealPhase')
fertility_days_df = create_cycle_df(menstrual_df, 'TotalDaysofFertility')

# Print the resulting DataFrames
print("Length of Cycle DataFrame:")
print(length_of_cycle_df)

print("\nEstimated Day of Ovulation DataFrame:")
print(estimated_ovulation_df)

print("\nLength of Luteal Phase DataFrame:")
print(luteal_phase_df)

print("\nTotal Days of Fertility DataFrame:")
print(fertility_days_df)
# Out:
# /var/folders/s4/47b93q1n5vj5dyx_x0hz9bqc0000gn/T/ipykernel_30876/214583988.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   cycle_values_df = pd.concat([cycle_values_df, pd.DataFrame([row_data])], ignore_index=True)
# /var/folders/s4/47b93q1n5vj5dyx_x0hz9bqc0000gn/T/ipykernel_30876/214583988.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   cycle_values_df = pd.concat([cycle_values_df, pd.DataFrame([row_data])], ignore_index=True)
# /var/folders/s4/47b93q1n5vj5dyx_x0hz9bqc0000gn/T/ipykernel_30876/214583988.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   cycle_values_df = pd.concat([cycle_values_df, pd.DataFrame([row_data])], ignore_index=True)
# Length of Cycle DataFrame:
#     ClientID Cycle_1 Cycle_2 Cycle_3 Cycle_4 Cycle_5 Cycle_6    Cycle_7  \
# 0    nfp8020      27      31      27      28      27      27         27
# 1    nfp8024      28      30      29      26      31      27         29
# 2    nfp8026      25      30      26      27      28      30  27.666667
# 3    nfp8030      29      29      26      25      29      23         26
# 4    nfp8031      27      27      28      27      27      29         28
# ..       ...     ...     ...     ...     ...     ...     ...        ...
# 154  nfp8322      38      32      31      38      33      35         32
# 155  nfp8323      34      32      35      29      36      29         34
# 156  nfp8324      30      23      19      32      37      36         51
# 157  nfp8328      35      34      32      29      31      32         30
# 158  nfp8334      28      28      29      30      30      32         29
#
#        Cycle_8    Cycle_9  ...   Cycle_37   Cycle_38   Cycle_39   Cycle_40  \
# 0           25         24  ...  25.875000  25.875000  25.875000  25.875000
# 1           34         27  ...  28.750000  28.750000  28.750000  28.750000
# 2    27.666667  27.666667  ...  27.666667  27.666667  27.666667  27.666667
# 3           25         30  ...  26.750000  26.750000  26.750000  26.750000
# 4           27         26  ...  27.166667  27.166667  27.166667  27.166667
# ..         ...        ...  ...        ...        ...        ...        ...
# 154         36         45  ...  37.083333  37.083333  37.083333  37.083333
# 155         29         27  ...  30.424242  30.424242  30.424242  30.424242
# 156         30         26  ...  33.166667  33.166667  33.166667  33.166667
# 157         31         28  ...  30.484848  30.484848  30.484848  30.484848
# 158         28         28  ...  29.636364  29.636364  29.636364  29.636364
#
#       Cycle_41   Cycle_42   Cycle_43   Cycle_44   Cycle_45  \
# 0    25.875000  25.875000  25.875000  25.875000  25.875000
# 1    28.750000  28.750000  28.750000  28.750000  28.750000
# 2    27.666667  27.666667  27.666667  27.666667  27.666667
# 3    26.750000  26.750000  26.750000  26.750000  26.750000
# 4    27.166667  27.166667  27.166667  27.166667  27.166667
# ..         ...        ...        ...        ...        ...
# 154  37.083333  37.083333  37.083333  37.083333  37.083333
# 155  30.424242  30.424242  30.424242  30.424242  30.424242
# 156  33.166667  33.166667  33.166667  33.166667  33.166667
# 157  30.484848  30.484848  30.484848  30.484848  30.484848
# 158  29.636364  29.636364  29.636364  29.636364  29.636364
#
#      MaxCycleWithAllValues
# 0                       45
# 1                       45
# 2                       45
# 3                       45
# 4                       45
# ..                     ...
# 154                     45
# 155                     45
# 156                     45
# 157                     45
# 158                     45
#
# [159 rows x 47 columns]
#
# Estimated Day of Ovulation DataFrame:
#     ClientID  Cycle_1  Cycle_2  Cycle_3  Cycle_4  Cycle_5  Cycle_6  Cycle_7  \
# 0    nfp8020     15.0     17.0     13.0     14.0     14.0     19.0     13.0
# 1    nfp8024     15.0     18.0     16.0     15.0     27.0     19.0     17.0
# 2    nfp8026      NaN     19.0     15.0     16.0     14.0     19.0      NaN
# 3    nfp8030     14.0     16.0     13.0     12.0     13.0     11.0     15.0
# 4    nfp8031      NaN     15.0     14.0      NaN     14.0     15.0     15.0
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 154  nfp8322     25.0      NaN     19.0     25.0     19.0      NaN     19.0
# 155  nfp8323     20.0     17.0     17.0     16.0     21.0     15.0     19.0
# 156  nfp8324     13.0     14.0      NaN     12.0      9.0     10.0     10.0
# 157  nfp8328     23.0     21.0     19.0     17.0     19.0     19.0     17.0
# 158  nfp8334     18.0     18.0     17.0     19.0     19.0     19.0     19.0
#
#      Cycle_8  Cycle_9  ...   Cycle_37   Cycle_38   Cycle_39   Cycle_40  \
# 0       13.0     15.0  ...  13.812500  13.812500  13.812500  13.812500
# 1       22.0     15.0  ...  17.583333  17.583333  17.583333  17.583333
# 2        NaN      NaN  ...        NaN        NaN        NaN        NaN
# 3       13.0     15.0  ...  13.375000  13.375000  13.375000  13.375000
# 4       14.0     13.0  ...        NaN        NaN        NaN        NaN
# ..       ...      ...  ...        ...        ...        ...        ...
# 154     20.0     28.0  ...        NaN        NaN        NaN        NaN
# 155     15.0     14.0  ...        NaN        NaN        NaN        NaN
# 156     10.0      9.0  ...        NaN        NaN        NaN        NaN
# 157     17.0     15.0  ...        NaN        NaN        NaN        NaN
# 158     17.0     16.0  ...        NaN        NaN        NaN        NaN
#
#       Cycle_41   Cycle_42   Cycle_43   Cycle_44   Cycle_45  \
# 0    13.812500  13.812500  13.812500  13.812500  13.812500
# 1    17.583333  17.583333  17.583333  17.583333  17.583333
# 2          NaN        NaN        NaN        NaN        NaN
# 3    13.375000  13.375000  13.375000  13.375000  13.375000
# 4          NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...
# 154        NaN        NaN        NaN        NaN        NaN
# 155        NaN        NaN        NaN        NaN        NaN
# 156        NaN        NaN        NaN        NaN        NaN
# 157        NaN        NaN        NaN        NaN        NaN
# 158        NaN        NaN        NaN        NaN        NaN
#
#      MaxCycleWithAllValues
# 0                       45
# 1                       45
# 2                        0
# 3                       45
# 4                        0
# ..                     ...
# 154                      1
# 155                     24
# 156                      2
# 157                     18
# 158                     10
#
# [159 rows x 47 columns]
#
# Length of Luteal Phase DataFrame:
#     ClientID  Cycle_1  Cycle_2  Cycle_3  Cycle_4  Cycle_5  Cycle_6  Cycle_7  \
# 0    nfp8020     12.0     14.0     14.0     14.0     13.0      8.0     14.0
# 1    nfp8024     13.0     12.0     13.0     11.0      4.0      8.0     12.0
# 2    nfp8026      NaN     11.0     11.0     11.0     14.0     11.0      NaN
# 3    nfp8030     15.0     13.0     13.0     13.0     16.0     12.0     11.0
# 4    nfp8031      NaN     12.0     14.0      NaN     13.0     14.0     13.0
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 154  nfp8322     13.0      NaN     12.0     13.0     14.0      NaN     13.0
# 155  nfp8323     14.0     15.0     18.0     13.0     15.0     14.0     15.0
# 156  nfp8324     17.0      9.0      NaN     20.0     28.0     26.0     41.0
# 157  nfp8328     12.0     13.0     13.0     12.0     12.0     13.0     13.0
# 158  nfp8334     10.0     10.0     12.0     11.0     11.0     13.0     10.0
#
#      Cycle_8  Cycle_9  ...   Cycle_37   Cycle_38   Cycle_39   Cycle_40  \
# 0       12.0      9.0  ...  12.062500  12.062500  12.062500  12.062500
# 1       12.0     12.0  ...  11.166667  11.166667  11.166667  11.166667
# 2        NaN      NaN  ...        NaN        NaN        NaN        NaN
# 3       12.0     15.0  ...  13.375000  13.375000  13.375000  13.375000
# 4       13.0     13.0  ...        NaN        NaN        NaN        NaN
# ..       ...      ...  ...        ...        ...        ...        ...
# 154     16.0     23.0  ...        NaN        NaN        NaN        NaN
# 155     14.0     13.0  ...        NaN        NaN        NaN        NaN
# 156     20.0     17.0  ...        NaN        NaN        NaN        NaN
# 157     14.0     13.0  ...        NaN        NaN        NaN        NaN
# 158     11.0     12.0  ...        NaN        NaN        NaN        NaN
#
#       Cycle_41   Cycle_42   Cycle_43   Cycle_44   Cycle_45  \
# 0    12.062500  12.062500  12.062500  12.062500  12.062500
# 1    11.166667  11.166667  11.166667  11.166667  11.166667
# 2          NaN        NaN        NaN        NaN        NaN
# 3    13.375000  13.375000  13.375000  13.375000  13.375000
# 4          NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...
# 154        NaN        NaN        NaN        NaN        NaN
# 155        NaN        NaN        NaN        NaN        NaN
# 156        NaN        NaN        NaN        NaN        NaN
# 157        NaN        NaN        NaN        NaN        NaN
# 158        NaN        NaN        NaN        NaN        NaN
#
#      MaxCycleWithAllValues
# 0                       45
# 1                       45
# 2                        0
# 3                       45
# 4                        0
# ..                     ...
# 154                      1
# 155                     24
# 156                      2
# 157                     18
# 158                     10
#
# [159 rows x 47 columns]
#
# Total Days of Fertility DataFrame:
#     ClientID  Cycle_1  Cycle_2  Cycle_3  Cycle_4  Cycle_5  Cycle_6  Cycle_7  \
# 0    nfp8020     12.0     10.0      7.0      6.0      8.0     13.0     10.0
# 1    nfp8024     10.0      6.0      9.0     10.0     10.0      5.0      8.0
# 2    nfp8026      4.0      9.0      8.0      7.0      7.0      7.0      7.0
# 3    nfp8030      7.0      9.0      7.0      6.0      7.0      7.0      8.0
# 4    nfp8031      8.0      5.0      6.0     12.0      5.0      6.0      6.0
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 154  nfp8322     11.0      5.0      9.0     13.0     11.0     18.0      6.0
# 155  nfp8323      7.0      7.0      7.0      9.0      7.0      7.0      8.0
# 156  nfp8324     11.0      9.0      4.0      8.0      8.0      8.0      7.0
# 157  nfp8328     16.0      8.0     12.0      9.0      8.0     10.0     10.0
# 158  nfp8334      9.0     11.0     10.0     13.0     10.0      8.0     10.0
#
#      Cycle_8  Cycle_9  ...   Cycle_37   Cycle_38   Cycle_39   Cycle_40  \
# 0        8.0      9.0  ...   8.312500   8.312500   8.312500   8.312500
# 1       14.0      7.0  ...   8.916667   8.916667   8.916667   8.916667
# 2        7.0      7.0  ...   7.000000   7.000000   7.000000   7.000000
# 3        6.0      8.0  ...   7.062500   7.062500   7.062500   7.062500
# 4        5.0      5.0  ...   6.583333   6.583333   6.583333   6.583333
# ..       ...      ...  ...        ...        ...        ...        ...
# 154      5.0     20.0  ...  10.000000  10.000000  10.000000  10.000000
# 155      5.0      6.0  ...   9.121212   9.121212   9.121212   9.121212
# 156      7.0      6.0  ...   7.250000   7.250000   7.250000   7.250000
# 157      7.0      9.0  ...  10.484848  10.484848  10.484848  10.484848
# 158      9.0      9.0  ...        NaN        NaN        NaN        NaN
#
#       Cycle_41   Cycle_42   Cycle_43   Cycle_44   Cycle_45  \
# 0     8.312500   8.312500   8.312500   8.312500   8.312500
# 1     8.916667   8.916667   8.916667   8.916667   8.916667
# 2     7.000000   7.000000   7.000000   7.000000   7.000000
# 3     7.062500   7.062500   7.062500   7.062500   7.062500
# 4     6.583333   6.583333   6.583333   6.583333   6.583333
# ..         ...        ...        ...        ...        ...
# 154  10.000000  10.000000  10.000000  10.000000  10.000000
# 155   9.121212   9.121212   9.121212   9.121212   9.121212
# 156   7.250000   7.250000   7.250000   7.250000   7.250000
# 157  10.484848  10.484848  10.484848  10.484848  10.484848
# 158        NaN        NaN        NaN        NaN        NaN
#
#      MaxCycleWithAllValues
# 0                       45
# 1                       45
# 2                       45
# 3                       45
# 4                       45
# ..                     ...
# 154                     45
# 155                     45
# 156                     45
# 157                     45
# 158                      9
#
# [159 rows x 47 columns]
# /var/folders/s4/47b93q1n5vj5dyx_x0hz9bqc0000gn/T/ipykernel_30876/214583988.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   cycle_values_df = pd.concat([cycle_values_df, pd.DataFrame([row_data])], ignore_index=True)

# %%
length_of_cycle_df.set_index('ClientID', inplace=True)
estimated_ovulation_df.set_index('ClientID', inplace=True)
luteal_phase_df.set_index('ClientID', inplace=True)
fertility_days_df.set_index('ClientID', inplace=True)
print(length_of_cycle_df)
# Out:
#          Cycle_1 Cycle_2 Cycle_3 Cycle_4 Cycle_5 Cycle_6    Cycle_7  \
# ClientID
# nfp8020       27      31      27      28      27      27         27
# nfp8024       28      30      29      26      31      27         29
# nfp8026       25      30      26      27      28      30  27.666667
# nfp8030       29      29      26      25      29      23         26
# nfp8031       27      27      28      27      27      29         28
# ...          ...     ...     ...     ...     ...     ...        ...
# nfp8322       38      32      31      38      33      35         32
# nfp8323       34      32      35      29      36      29         34
# nfp8324       30      23      19      32      37      36         51
# nfp8328       35      34      32      29      31      32         30
# nfp8334       28      28      29      30      30      32         29
#
#             Cycle_8    Cycle_9   Cycle_10  ...   Cycle_37   Cycle_38  \
# ClientID                                   ...
# nfp8020          25         24         18  ...  25.875000  25.875000
# nfp8024          34         27         28  ...  28.750000  28.750000
# nfp8026   27.666667  27.666667  27.666667  ...  27.666667  27.666667
# nfp8030          25         30         27  ...  26.750000  26.750000
# nfp8031          27         26         28  ...  27.166667  27.166667
# ...             ...        ...        ...  ...        ...        ...
# nfp8322          36         45         42  ...  37.083333  37.083333
# nfp8323          29         27         35  ...  30.424242  30.424242
# nfp8324          30         26         43  ...  33.166667  33.166667
# nfp8328          31         28         36  ...  30.484848  30.484848
# nfp8334          28         28         40  ...  29.636364  29.636364
#
#            Cycle_39   Cycle_40   Cycle_41   Cycle_42   Cycle_43   Cycle_44  \
# ClientID
# nfp8020   25.875000  25.875000  25.875000  25.875000  25.875000  25.875000
# nfp8024   28.750000  28.750000  28.750000  28.750000  28.750000  28.750000
# nfp8026   27.666667  27.666667  27.666667  27.666667  27.666667  27.666667
# nfp8030   26.750000  26.750000  26.750000  26.750000  26.750000  26.750000
# nfp8031   27.166667  27.166667  27.166667  27.166667  27.166667  27.166667
# ...             ...        ...        ...        ...        ...        ...
# nfp8322   37.083333  37.083333  37.083333  37.083333  37.083333  37.083333
# nfp8323   30.424242  30.424242  30.424242  30.424242  30.424242  30.424242
# nfp8324   33.166667  33.166667  33.166667  33.166667  33.166667  33.166667
# nfp8328   30.484848  30.484848  30.484848  30.484848  30.484848  30.484848
# nfp8334   29.636364  29.636364  29.636364  29.636364  29.636364  29.636364
#
#            Cycle_45  MaxCycleWithAllValues
# ClientID
# nfp8020   25.875000                     45
# nfp8024   28.750000                     45
# nfp8026   27.666667                     45
# nfp8030   26.750000                     45
# nfp8031   27.166667                     45
# ...             ...                    ...
# nfp8322   37.083333                     45
# nfp8323   30.424242                     45
# nfp8324   33.166667                     45
# nfp8328   30.484848                     45
# nfp8334   29.636364                     45
#
# [159 rows x 46 columns]

# %%
# making all the object types into a numerical format
encoder = LabelEncoder()

def convert_cat_cols_to_numeric(df):
    # Identify categorical columns

    categorical_columns = df.select_dtypes(include= object).columns
    print(categorical_columns)
    for cols in categorical_columns:
        df[cols] = pd.to_numeric(df[cols])
        #df[cols] = encoder.fit_transform(df[cols])
    return df

length_of_cycle_df = convert_cat_cols_to_numeric(length_of_cycle_df)
estimated_ovulation_df = convert_cat_cols_to_numeric(estimated_ovulation_df)
luteal_phase_df = convert_cat_cols_to_numeric(luteal_phase_df)
fertility_days = convert_cat_cols_to_numeric(fertility_days_df)
# Out:
# Index([], dtype='object')
# Index([], dtype='object')
# Index([], dtype='object')
# Index([], dtype='object')

# %%
categorical_columns = length_of_cycle_df.select_dtypes(include= object).columns
print(categorical_columns)
# Out:
# Index([], dtype='object')

# %%
# getting the location and scale parameters
print(length_of_cycle_df.describe().T)
print(estimated_ovulation_df.describe().T)
print(luteal_phase_df.describe().T)
print(fertility_days.describe().T)
# Out:
#                        count       mean       std   min        25%        50%  \
# Cycle_1                159.0  30.037736  3.945654  24.0  27.000000  29.000000
# Cycle_2                159.0  29.635220  3.759244  23.0  27.000000  29.000000
# Cycle_3                159.0  29.767296  3.869624  19.0  27.000000  29.000000
# Cycle_4                159.0  29.773585  4.093676  20.0  27.000000  29.000000
# Cycle_5                159.0  29.723270  3.586206  22.0  27.000000  29.000000
# Cycle_6                159.0  29.709434  3.551511  21.0  27.000000  29.000000
# Cycle_7                159.0  29.649686  4.001579  21.0  27.000000  29.000000
# Cycle_8                159.0  29.384636  3.398236  21.0  27.000000  29.000000
# Cycle_9                159.0  29.618913  4.051501  21.0  27.000000  29.000000
# Cycle_10               159.0  29.793616  4.100955  18.0  27.000000  29.000000
# Cycle_11               159.0  29.974119  4.302805  24.0  27.000000  29.000000
# Cycle_12               159.0  29.591043  3.494234  23.0  27.000000  29.000000
# Cycle_13               159.0  29.634020  3.475103  18.0  27.000000  29.416667
# Cycle_14               159.0  29.607895  3.184490  23.0  27.115385  29.400000
# Cycle_15               159.0  29.667644  3.241614  24.0  27.038462  29.416667
# Cycle_16               159.0  29.730537  3.036152  24.0  27.226190  29.500000
# Cycle_17               159.0  29.622439  3.049429  24.0  27.160256  29.400000
# Cycle_18               159.0  29.747115  3.141971  24.0  27.226190  29.500000
# Cycle_19               159.0  29.578702  3.068708  24.0  27.038462  29.400000
# Cycle_20               159.0  29.767381  3.177749  24.0  27.160256  29.500000
# Cycle_21               159.0  29.678073  3.085541  23.0  27.226190  29.500000
# Cycle_22               159.0  29.627758  3.069548  24.0  27.115385  29.416667
# Cycle_23               159.0  29.662064  3.128761  23.0  27.038462  29.500000
# Cycle_24               159.0  29.666986  3.047230  24.0  27.160256  29.416667
# Cycle_25               159.0  29.673275  3.075821  24.0  27.160256  29.500000
# Cycle_26               159.0  29.773904  3.119591  24.0  27.321429  29.500000
# Cycle_27               159.0  29.692143  3.039498  24.0  27.226190  29.416667
# Cycle_28               159.0  29.710778  3.060056  24.0  27.226190  29.500000
# Cycle_29               159.0  29.616438  3.120382  24.0  27.038462  29.500000
# Cycle_30               159.0  29.673042  3.054159  24.0  27.226190  29.416667
# Cycle_31               159.0  29.654174  3.079935  24.0  27.226190  29.416667
# Cycle_32               159.0  29.708140  3.053441  24.0  27.226190  29.500000
# Cycle_33               159.0  29.657433  3.071281  24.0  27.115385  29.500000
# Cycle_34               159.0  29.688308  3.058505  24.0  27.160256  29.500000
# Cycle_35               159.0  29.694597  3.053967  24.0  27.226190  29.500000
# Cycle_36               159.0  29.688308  3.058505  24.0  27.160256  29.500000
# Cycle_37               159.0  29.682018  3.065089  24.0  27.160256  29.500000
# Cycle_38               159.0  29.694597  3.053967  24.0  27.226190  29.500000
# Cycle_39               159.0  29.694597  3.053967  24.0  27.226190  29.500000
# Cycle_40               159.0  29.669440  3.084339  24.0  27.160256  29.500000
# Cycle_41               159.0  29.682018  3.065089  24.0  27.160256  29.500000
# Cycle_42               159.0  29.688308  3.058505  24.0  27.160256  29.500000
# Cycle_43               159.0  29.694597  3.053967  24.0  27.226190  29.500000
# Cycle_44               159.0  29.688308  3.058505  24.0  27.160256  29.500000
# Cycle_45               159.0  29.694597  3.053967  24.0  27.226190  29.500000
# MaxCycleWithAllValues  159.0  45.000000  0.000000  45.0  45.000000  45.000000
#
#                              75%   max
# Cycle_1                32.000000  48.0
# Cycle_2                32.000000  42.0
# Cycle_3                32.000000  43.0
# Cycle_4                32.000000  40.0
# Cycle_5                32.000000  42.0
# Cycle_6                32.000000  44.0
# Cycle_7                31.200000  51.0
# Cycle_8                32.000000  40.0
# Cycle_9                32.000000  48.0
# Cycle_10               32.000000  43.0
# Cycle_11               31.800000  54.0
# Cycle_12               31.800000  42.0
# Cycle_13               31.366667  40.0
# Cycle_14               31.154762  42.0
# Cycle_15               31.166667  43.0
# Cycle_16               31.366667  40.0
# Cycle_17               31.250000  40.0
# Cycle_18               31.408333  40.0
# Cycle_19               31.250000  40.0
# Cycle_20               31.366667  40.0
# Cycle_21               31.333333  40.0
# Cycle_22               31.250000  40.0
# Cycle_23               31.366667  40.0
# Cycle_24               31.333333  40.0
# Cycle_25               31.333333  40.0
# Cycle_26               31.500000  40.0
# Cycle_27               31.333333  40.0
# Cycle_28               31.366667  40.0
# Cycle_29               31.333333  40.0
# Cycle_30               31.333333  40.0
# Cycle_31               31.333333  40.0
# Cycle_32               31.333333  40.0
# Cycle_33               31.333333  40.0
# Cycle_34               31.333333  40.0
# Cycle_35               31.333333  40.0
# Cycle_36               31.333333  40.0
# Cycle_37               31.333333  40.0
# Cycle_38               31.333333  40.0
# Cycle_39               31.333333  40.0
# Cycle_40               31.333333  40.0
# Cycle_41               31.333333  40.0
# Cycle_42               31.333333  40.0
# Cycle_43               31.333333  40.0
# Cycle_44               31.333333  40.0
# Cycle_45               31.333333  40.0
# MaxCycleWithAllValues  45.000000  45.0
#                        count       mean        std   min        25%  \
# Cycle_1                144.0  16.868056   4.014391  11.0  14.000000
# Cycle_2                143.0  16.587413   3.713942   6.0  14.000000
# Cycle_3                143.0  16.472028   3.574054  11.0  14.000000
# Cycle_4                141.0  16.797872   4.150818  11.0  14.000000
# Cycle_5                139.0  16.390288   3.795497   8.0  14.000000
# Cycle_6                139.0  16.368705   3.741577  10.0  14.000000
# Cycle_7                138.0  16.336353   3.567909  10.0  14.000000
# Cycle_8                134.0  16.126777   3.542846   9.0  14.000000
# Cycle_9                130.0  16.050870   3.747962   9.0  13.000000
# Cycle_10               131.0  16.513586   4.006711   8.0  14.000000
# Cycle_11               131.0  16.315876   3.528040   9.0  14.000000
# Cycle_12               126.0  16.251932   3.550833   9.0  14.000000
# Cycle_13               112.0  16.348155   3.498419  10.6  14.000000
# Cycle_14               104.0  16.129374   3.575562  10.0  13.912500
# Cycle_15               103.0  16.264472   3.564927  10.0  13.873077
# Cycle_16               102.0  16.263144   3.359322  10.0  14.000000
# Cycle_17                99.0  16.170739   3.364060  10.6  13.873077
# Cycle_18                99.0  16.201042   3.366917  10.0  13.873077
# Cycle_19                98.0  16.101053   3.413046  10.6  13.578125
# Cycle_20                98.0  16.427583   3.515834  10.6  13.904167
# Cycle_21                96.0  16.200554   3.415450   8.0  13.912500
# Cycle_22                98.0  16.155644   3.360920  10.6  13.859615
# Cycle_23                97.0  16.254250   3.348109  10.6  13.900000
# Cycle_24                96.0  16.246482   3.317548  10.6  13.912500
# Cycle_25                96.0  16.256898   3.318336  10.6  13.912500
# Cycle_26                97.0  16.408889   3.355960  10.6  14.000000
# Cycle_27                96.0  16.288148   3.301424  10.6  13.979167
# Cycle_28                95.0  16.367595   3.325665  10.6  13.958333
# Cycle_29                95.0  16.241279   3.369056  10.6  13.908333
# Cycle_30                94.0  16.307676   3.330509  10.6  13.937500
# Cycle_31                96.0  16.238766   3.376402   9.0  13.912500
# Cycle_32                94.0  16.382144   3.346888  10.6  13.937500
# Cycle_33                94.0  16.321306   3.330546  10.6  13.937500
# Cycle_34                93.0  16.324761   3.348429  10.6  13.916667
# Cycle_35                93.0  16.324761   3.348429  10.6  13.916667
# Cycle_36                92.0  16.339160   3.363880  10.6  13.912500
# Cycle_37                93.0  16.314008   3.354330  10.6  13.916667
# Cycle_38                93.0  16.335513   3.345733  10.6  13.916667
# Cycle_39                93.0  16.335513   3.345733  10.6  13.916667
# Cycle_40                93.0  16.314008   3.354330  10.6  13.916667
# Cycle_41                93.0  16.314008   3.354330  10.6  13.916667
# Cycle_42                92.0  16.339160   3.363880  10.6  13.912500
# Cycle_43                93.0  16.324761   3.348429  10.6  13.916667
# Cycle_44                93.0  16.335513   3.345733  10.6  13.916667
# Cycle_45                93.0  16.335513   3.345733  10.6  13.916667
# MaxCycleWithAllValues  159.0  27.955975  20.439582   0.0   3.000000
#
#                              50%        75%   max
# Cycle_1                16.000000  19.000000  29.0
# Cycle_2                16.000000  18.000000  29.0
# Cycle_3                16.000000  18.000000  29.0
# Cycle_4                16.000000  19.000000  28.0
# Cycle_5                15.666667  19.000000  27.0
# Cycle_6                16.000000  19.000000  29.0
# Cycle_7                16.000000  19.000000  27.0
# Cycle_8                16.000000  18.000000  26.0
# Cycle_9                15.000000  18.000000  28.0
# Cycle_10               16.000000  18.321429  29.0
# Cycle_11               15.500000  18.750000  26.0
# Cycle_12               15.833333  19.000000  26.0
# Cycle_13               15.125000  18.375000  26.0
# Cycle_14               15.464286  18.187500  28.0
# Cycle_15               15.666667  18.154762  28.0
# Cycle_16               16.000000  18.229167  26.0
# Cycle_17               15.428571  18.281250  26.0
# Cycle_18               15.666667  18.281250  26.0
# Cycle_19               15.339286  18.229167  26.0
# Cycle_20               15.833333  18.458333  26.0
# Cycle_21               15.583333  18.265625  26.0
# Cycle_22               15.464286  18.229167  26.0
# Cycle_23               15.428571  18.312500  26.0
# Cycle_24               15.418831  18.265625  26.0
# Cycle_25               15.583333  18.265625  26.0
# Cycle_26               16.000000  18.500000  26.0
# Cycle_27               15.833333  18.265625  26.0
# Cycle_28               16.000000  18.322917  26.0
# Cycle_29               15.500000  18.281250  26.0
# Cycle_30               15.583333  18.296875  26.0
# Cycle_31               15.833333  18.265625  26.0
# Cycle_32               16.000000  18.328125  26.0
# Cycle_33               15.833333  18.296875  26.0
# Cycle_34               15.666667  18.312500  26.0
# Cycle_35               15.666667  18.312500  26.0
# Cycle_36               15.833333  18.317708  26.0
# Cycle_37               15.666667  18.312500  26.0
# Cycle_38               16.000000  18.312500  26.0
# Cycle_39               16.000000  18.312500  26.0
# Cycle_40               15.666667  18.312500  26.0
# Cycle_41               15.666667  18.312500  26.0
# Cycle_42               15.833333  18.317708  26.0
# Cycle_43               15.666667  18.312500  26.0
# Cycle_44               16.000000  18.312500  26.0
# Cycle_45               16.000000  18.312500  26.0
# MaxCycleWithAllValues  45.000000  45.000000  45.0
#                        count       mean        std  min        25%        50%  \
# Cycle_1                144.0  13.069444   2.496579  6.0  12.000000  13.000000
# Cycle_2                143.0  12.881119   3.019863  1.0  11.500000  13.000000
# Cycle_3                143.0  13.080420   2.833185  5.0  12.000000  13.000000
# Cycle_4                141.0  12.897163   2.574190  4.0  12.000000  13.000000
# Cycle_5                139.0  13.223022   2.819485  4.0  12.000000  13.000000
# Cycle_6                139.0  13.202878   2.906643  4.0  12.000000  13.000000
# Cycle_7                138.0  13.130676   3.371216  4.0  12.000000  13.000000
# Cycle_8                134.0  13.179353   2.529620  6.0  12.000000  13.000000
# Cycle_9                130.0  13.418526   2.602166  6.0  12.000000  13.000000
# Cycle_10               131.0  13.217706   3.010610  6.0  11.816667  13.000000
# Cycle_11               131.0  13.559690   3.183084  6.0  12.000000  13.000000
# Cycle_12               126.0  13.099216   2.602314  6.0  12.000000  13.000000
# Cycle_13               112.0  13.066976   2.198612  6.0  12.000000  13.000000
# Cycle_14               104.0  13.136477   2.303949  6.0  11.958333  13.153846
# Cycle_15               103.0  13.121158   2.241061  6.0  12.000000  13.153846
# Cycle_16               102.0  13.169405   2.205989  6.0  12.000000  13.153846
# Cycle_17                99.0  13.122771   2.195799  6.0  12.000000  13.153846
# Cycle_18                99.0  13.203579   2.226692  6.0  12.000000  13.153846
# Cycle_19                98.0  13.154636   2.179234  6.0  12.000000  13.333333
# Cycle_20                98.0  13.175044   2.205896  6.0  12.000000  13.333333
# Cycle_21                96.0  13.152649   2.205294  6.0  12.000000  13.243590
# Cycle_22                98.0  13.108717   2.137284  6.0  12.000000  13.243590
# Cycle_23                97.0  13.130457   2.166510  6.0  12.000000  13.153846
# Cycle_24                96.0  13.110982   2.169332  6.0  12.000000  13.243590
# Cycle_25                96.0  13.079732   2.182809  6.0  11.958333  13.076923
# Cycle_26                97.0  13.109838   2.158033  6.0  12.000000  13.153846
# Cycle_27                96.0  13.100565   2.181939  6.0  11.958333  13.153846
# Cycle_28                95.0  13.101624   2.183768  6.0  12.000000  13.153846
# Cycle_29                95.0  13.091098   2.181801  6.0  12.000000  13.000000
# Cycle_30                94.0  13.113343   2.207136  6.0  12.000000  13.153846
# Cycle_31                95.0  13.101624   2.183768  6.0  12.000000  13.153846
# Cycle_32                94.0  13.092067   2.193479  6.0  12.000000  13.076923
# Cycle_33                94.0  13.099048   2.192542  6.0  12.000000  13.153846
# Cycle_34                93.0  13.089361   2.202402  6.0  12.000000  13.153846
# Cycle_35                93.0  13.100113   2.199465  6.0  12.000000  13.153846
# Cycle_36                92.0  13.101201   2.211492  6.0  11.958333  13.153846
# Cycle_37                93.0  13.089361   2.202402  6.0  12.000000  13.153846
# Cycle_38                93.0  13.089361   2.202402  6.0  12.000000  13.153846
# Cycle_39                93.0  13.089361   2.202402  6.0  12.000000  13.153846
# Cycle_40                93.0  13.067855   2.222825  6.0  11.833333  13.153846
# Cycle_41                93.0  13.089361   2.202402  6.0  12.000000  13.153846
# Cycle_42                92.0  13.101201   2.211492  6.0  11.958333  13.153846
# Cycle_43                93.0  13.100113   2.199465  6.0  12.000000  13.153846
# Cycle_44                93.0  13.078608   2.210206  6.0  11.833333  13.153846
# Cycle_45                93.0  13.089361   2.202402  6.0  12.000000  13.153846
# MaxCycleWithAllValues  159.0  27.955975  20.439582  0.0   3.000000  45.000000
#
#                              75%   max
# Cycle_1                15.000000  22.0
# Cycle_2                14.000000  29.0
# Cycle_3                14.000000  24.0
# Cycle_4                14.000000  20.0
# Cycle_5                14.500000  28.0
# Cycle_6                14.500000  26.0
# Cycle_7                14.000000  41.0
# Cycle_8                14.000000  23.0
# Cycle_9                15.000000  23.0
# Cycle_10               14.000000  34.0
# Cycle_11               14.055556  32.0
# Cycle_12               14.232323  26.0
# Cycle_13               14.151515  20.0
# Cycle_14               14.287879  20.0
# Cycle_15               14.243506  20.0
# Cycle_16               14.258117  20.0
# Cycle_17               14.243506  20.0
# Cycle_18               14.348485  20.0
# Cycle_19               14.258117  20.0
# Cycle_20               14.258117  20.0
# Cycle_21               14.287879  20.0
# Cycle_22               14.068182  20.0
# Cycle_23               14.214286  20.0
# Cycle_24               14.095960  20.0
# Cycle_25               14.136905  20.0
# Cycle_26               14.090909  20.0
# Cycle_27               14.136905  20.0
# Cycle_28               14.162698  20.0
# Cycle_29               14.162698  20.0
# Cycle_30               14.188492  20.0
# Cycle_31               14.162698  20.0
# Cycle_32               14.188492  20.0
# Cycle_33               14.188492  20.0
# Cycle_34               14.214286  20.0
# Cycle_35               14.214286  20.0
# Cycle_36               14.228896  20.0
# Cycle_37               14.214286  20.0
# Cycle_38               14.214286  20.0
# Cycle_39               14.214286  20.0
# Cycle_40               14.214286  20.0
# Cycle_41               14.214286  20.0
# Cycle_42               14.228896  20.0
# Cycle_43               14.214286  20.0
# Cycle_44               14.214286  20.0
# Cycle_45               14.214286  20.0
# MaxCycleWithAllValues  45.000000  45.0
#                        count       mean       std  min        25%        50%  \
# Cycle_1                157.0   8.745223  3.684521  4.0   6.000000   8.000000
# Cycle_2                157.0   8.203822  3.576524  0.0   6.000000   8.000000
# Cycle_3                157.0   8.140127  3.482481  0.0   6.000000   7.000000
# Cycle_4                157.0   8.263270  3.723631  0.0   6.000000   7.333333
# Cycle_5                157.0   8.137473  3.227346  0.0   6.000000   7.666667
# Cycle_6                157.0   8.190977  3.120754  2.5   6.000000   7.333333
# Cycle_7                157.0   8.188854  3.122196  0.0   6.000000   7.666667
# Cycle_8                156.0   7.942811  3.098682  0.0   6.000000   7.690476
# Cycle_9                156.0   8.373901  3.311956  0.0   6.000000   8.000000
# Cycle_10               156.0   7.821195  3.341460  0.0   6.000000   7.000000
# Cycle_11               155.0   7.989073  3.378714  0.0   6.000000   7.000000
# Cycle_12               156.0   8.274108  3.374037  0.0   6.000000   8.000000
# Cycle_13               153.0   8.150398  3.026565  0.0   6.000000   7.916667
# Cycle_14               152.0   8.072946  2.864576  0.0   6.245192   7.757143
# Cycle_15               152.0   8.052269  2.744023  2.0   6.362500   7.714286
# Cycle_16               152.0   8.180340  2.707749  2.5   6.362500   7.912879
# Cycle_17               151.0   8.148835  2.786109  0.0   6.430769   7.909091
# Cycle_18               151.0   8.082221  2.738377  0.0   6.480769   7.846154
# Cycle_19               151.0   8.194068  2.721706  2.5   6.666667   7.888889
# Cycle_20               151.0   8.147710  2.669013  2.5   6.613095   7.846154
# Cycle_21               151.0   8.128505  2.740262  0.0   6.541667   7.888889
# Cycle_22               151.0   8.128505  2.651233  2.5   6.541667   7.909091
# Cycle_23               151.0   8.195031  2.679686  2.5   6.654762   7.916667
# Cycle_24               151.0   8.194455  2.667704  2.5   6.654762   7.909091
# Cycle_25               151.0   8.181210  2.663642  2.5   6.613095   7.916667
# Cycle_26               151.0   8.240813  2.680112  2.5   6.654762   8.000000
# Cycle_27               151.0   8.227567  2.778953  2.5   6.613095   7.909091
# Cycle_28               151.0   8.164776  2.636801  2.5   6.654762   7.888889
# Cycle_29               151.0   8.197889  2.722859  2.5   6.613095   7.916667
# Cycle_30               151.0   8.303849  2.828506  2.5   6.666667   7.925926
# Cycle_31               151.0   8.125041  2.638998  2.5   6.541667   7.909091
# Cycle_32               151.0   8.237197  2.729489  2.5   6.654762   7.916667
# Cycle_33               151.0   8.200359  2.774156  2.5   6.541667   7.909091
# Cycle_34               151.0   8.177882  2.620568  2.5   6.654762   7.916667
# Cycle_35               151.0   8.171260  2.624825  2.5   6.613095   7.916667
# Cycle_36               151.0   8.217618  2.647935  2.5   6.654762   7.925926
# Cycle_37               151.0   8.164637  2.631593  2.5   6.613095   7.916667
# Cycle_38               151.0   8.171260  2.624825  2.5   6.613095   7.916667
# Cycle_39               151.0   8.191128  2.619630  2.5   6.654762   7.925926
# Cycle_40               151.0   8.184505  2.618835  2.5   6.654762   7.925926
# Cycle_41               151.0   8.197750  2.622950  2.5   6.654762   7.925926
# Cycle_42               151.0   8.204373  2.628787  2.5   6.654762   7.925926
# Cycle_43               151.0   8.204373  2.628787  2.5   6.654762   7.925926
# Cycle_44               151.0   8.184505  2.618835  2.5   6.654762   7.925926
# Cycle_45               151.0   8.224240  2.661193  2.5   6.654762   7.925926
# MaxCycleWithAllValues  159.0  43.044025  8.592273  0.0  45.000000  45.000000
#
#                              75%   max
# Cycle_1                10.000000  24.0
# Cycle_2                10.000000  22.0
# Cycle_3                10.000000  20.0
# Cycle_4                10.000000  27.0
# Cycle_5                10.000000  21.5
# Cycle_6                10.000000  21.5
# Cycle_7                 9.200000  21.5
# Cycle_8                 9.000000  21.5
# Cycle_9                10.000000  21.5
# Cycle_10                9.000000  21.5
# Cycle_11                9.250000  21.5
# Cycle_12               10.000000  21.5
# Cycle_13                9.300000  21.5
# Cycle_14                9.230769  21.5
# Cycle_15                9.230769  21.5
# Cycle_16                9.413462  21.5
# Cycle_17                9.370879  21.5
# Cycle_18                9.230769  21.5
# Cycle_19                9.230769  21.5
# Cycle_20                9.230769  21.5
# Cycle_21                9.230769  21.5
# Cycle_22                9.215385  21.5
# Cycle_23                9.230769  21.5
# Cycle_24                9.230769  21.5
# Cycle_25                9.230769  21.5
# Cycle_26                9.230769  21.5
# Cycle_27                9.230769  21.5
# Cycle_28                9.230769  21.5
# Cycle_29                9.230769  21.5
# Cycle_30                9.265385  21.5
# Cycle_31                9.215385  21.5
# Cycle_32                9.230769  21.5
# Cycle_33                9.230769  21.5
# Cycle_34                9.230769  21.5
# Cycle_35                9.230769  21.5
# Cycle_36                9.230769  21.5
# Cycle_37                9.230769  21.5
# Cycle_38                9.230769  21.5
# Cycle_39                9.230769  21.5
# Cycle_40                9.230769  21.5
# Cycle_41                9.230769  21.5
# Cycle_42                9.230769  21.5
# Cycle_43                9.230769  21.5
# Cycle_44                9.230769  21.5
# Cycle_45                9.230769  21.5
# MaxCycleWithAllValues  45.000000  45.0

# %%
def scale_data(df):
    # Ensure the DataFrame is a copy to avoid modifying the original
    df = df.copy()
    # Extract column names excluding the last column
    columns_to_scale = df.columns[:-1]  # All columns except the last one

    # Initialize MinMaxScaler
    scaler = MinMaxScaler()

    # Scale the columns excluding the last one
    X = df[columns_to_scale].values
    X_scaled = scaler.fit_transform(X)

    # Create a new DataFrame with the scaled values
    df_scaled = pd.DataFrame(X_scaled, columns=columns_to_scale, index=df.index)

    # Reattach the last column without scaling
    df_scaled[df.columns[-1]] = df[df.columns[-1]]

    return df_scaled, scaler

# %%
def unscale_data(df_scaled, scaler):
    # Extract column names excluding the last column
    columns_to_unscale = df_scaled.columns[:-1]

    # Get the scaled values and apply inverse transform
    X_scaled = df_scaled[columns_to_unscale].values
    X_unscaled = scaler.inverse_transform(X_scaled)

    # Create a new DataFrame with the unscaled values
    df_unscaled = pd.DataFrame(X_unscaled, columns=columns_to_unscale, index=df_scaled.index)

    # Reattach the last column without scaling
    df_unscaled[df_scaled.columns[-1]] = df_scaled[df_scaled.columns[-1]]

    return df_unscaled

# %%
# Storing the scaled dataframes and the scaler to unscale later on
length_of_cycle_df_scaled, cycle_length_scaler = scale_data(length_of_cycle_df)
estimated_ovulation_df_scaled, ovulation_scaler = scale_data(estimated_ovulation_df)
luteal_phase_df_scaled, luteal_scaler = scale_data(luteal_phase_df)
fertility_days_scaled, fertility_scaler = scale_data(fertility_days)

# %%
print(length_of_cycle_df_scaled)
# Out:
#            Cycle_1   Cycle_2   Cycle_3  Cycle_4  Cycle_5   Cycle_6   Cycle_7  \
# ClientID
# nfp8020   0.125000  0.421053  0.333333     0.40     0.25  0.260870  0.200000
# nfp8024   0.166667  0.368421  0.416667     0.30     0.45  0.260870  0.266667
# nfp8026   0.041667  0.368421  0.291667     0.35     0.30  0.391304  0.222222
# nfp8030   0.208333  0.315789  0.291667     0.25     0.35  0.086957  0.166667
# nfp8031   0.125000  0.210526  0.375000     0.35     0.25  0.347826  0.233333
# ...            ...       ...       ...      ...      ...       ...       ...
# nfp8322   0.583333  0.473684  0.500000     0.90     0.55  0.608696  0.366667
# nfp8323   0.416667  0.473684  0.666667     0.45     0.70  0.347826  0.433333
# nfp8324   0.250000  0.000000  0.000000     0.60     0.75  0.652174  1.000000
# nfp8328   0.458333  0.578947  0.541667     0.45     0.45  0.478261  0.300000
# nfp8334   0.166667  0.263158  0.416667     0.50     0.40  0.478261  0.266667
#
#            Cycle_8   Cycle_9  Cycle_10  ...  Cycle_37  Cycle_38  Cycle_39  \
# ClientID                                ...
# nfp8020   0.210526  0.111111  0.000000  ...  0.117188  0.117188  0.117188
# nfp8024   0.684211  0.222222  0.400000  ...  0.296875  0.296875  0.296875
# nfp8026   0.350877  0.246914  0.386667  ...  0.229167  0.229167  0.229167
# nfp8030   0.210526  0.333333  0.360000  ...  0.171875  0.171875  0.171875
# nfp8031   0.315789  0.185185  0.400000  ...  0.197917  0.197917  0.197917
# ...            ...       ...       ...  ...       ...       ...       ...
# nfp8322   0.789474  0.888889  0.960000  ...  0.817708  0.817708  0.817708
# nfp8323   0.421053  0.222222  0.680000  ...  0.401515  0.401515  0.401515
# nfp8324   0.473684  0.185185  1.000000  ...  0.572917  0.572917  0.572917
# nfp8328   0.526316  0.259259  0.720000  ...  0.405303  0.405303  0.405303
# nfp8334   0.368421  0.259259  0.880000  ...  0.352273  0.352273  0.352273
#
#           Cycle_40  Cycle_41  Cycle_42  Cycle_43  Cycle_44  Cycle_45  \
# ClientID
# nfp8020   0.117188  0.117188  0.117188  0.117188  0.117188  0.117188
# nfp8024   0.296875  0.296875  0.296875  0.296875  0.296875  0.296875
# nfp8026   0.229167  0.229167  0.229167  0.229167  0.229167  0.229167
# nfp8030   0.171875  0.171875  0.171875  0.171875  0.171875  0.171875
# nfp8031   0.197917  0.197917  0.197917  0.197917  0.197917  0.197917
# ...            ...       ...       ...       ...       ...       ...
# nfp8322   0.817708  0.817708  0.817708  0.817708  0.817708  0.817708
# nfp8323   0.401515  0.401515  0.401515  0.401515  0.401515  0.401515
# nfp8324   0.572917  0.572917  0.572917  0.572917  0.572917  0.572917
# nfp8328   0.405303  0.405303  0.405303  0.405303  0.405303  0.405303
# nfp8334   0.352273  0.352273  0.352273  0.352273  0.352273  0.352273
#
#           MaxCycleWithAllValues
# ClientID
# nfp8020                      45
# nfp8024                      45
# nfp8026                      45
# nfp8030                      45
# nfp8031                      45
# ...                         ...
# nfp8322                      45
# nfp8323                      45
# nfp8324                      45
# nfp8328                      45
# nfp8334                      45
#
# [159 rows x 46 columns]

# %%
def prepare_data_for_lstm(df):
    X = []
    y = []

    # Iterate over each row in the dataframe
    for _, row in df.iterrows():
        # Get the max valid column index from the last column
        max_valid_index = int(row[-1])

        # Get the sequence of valid inputs (up to the second last valid value)
        valid_sequence = row[:max_valid_index - 1]
        #print("Valid Sequence")
        #print(valid_sequence)

        # The target value (to predict) is the value of the max valid index
        target_value = row[max_valid_index - 1]
        #print("Target")
        #print(target_value)

        # Append the sequence to X and the target value to y
        X.append(valid_sequence)
        y.append(target_value)

    # Return the sequences (X) and targets (y)
    return X, y

# %%
def pad_sequences_only(X, y):
    # Pad sequences to make them the same length (only padding, no scaling)
    X_padded = pad_sequences(X, padding='post', dtype='float32')

    # Convert y to numpy array (y is already scaled)
    y = np.array(y)

    return X_padded, y

# %%
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(100, activation='relu', input_shape=input_shape, return_sequences=True))
    model.add(LSTM(50, activation='relu'))
    model.add(Dense(1))  # Output layer with 1 neuron for the regression task
    model.compile(optimizer='adam', loss='mse')
    return model

# %% [markdown]
# Length Cycle

# %%
# preparing data for LSTM
X_length_cycle, y_length_cycle = prepare_data_for_lstm(length_of_cycle_df_scaled)
# padding data for LSTM
X_length_cycle_padded, y_length_cycle = pad_sequences_only(X_length_cycle, y_length_cycle)
# test train split
X_lc_train, X_lc_test, y_lc_train, y_lc_test = train_test_split(X_length_cycle_padded,  y_length_cycle, test_size=0.2, random_state=42)
# Out:
# /var/folders/s4/47b93q1n5vj5dyx_x0hz9bqc0000gn/T/ipykernel_30876/836010761.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   max_valid_index = int(row[-1])
# /var/folders/s4/47b93q1n5vj5dyx_x0hz9bqc0000gn/T/ipykernel_30876/836010761.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   target_value = row[max_valid_index - 1]

# %%
input_shape_lc = (X_lc_train.shape[1], 1)  # (timesteps, features)

# Reshape the input data for LSTM (LSTM expects 3D input: [samples, timesteps, features])
X_lc_train = X_lc_train.reshape((X_lc_train.shape[0], X_lc_train.shape[1], 1))
X_lc_test = X_lc_test.reshape((X_lc_test.shape[0], X_lc_test.shape[1], 1))

# Create the LSTM model
model_lc = create_lstm_model(input_shape_lc)

# Train the model and store the history
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model_lc.fit(X_lc_train, y_lc_train, epochs=100, batch_size=32, validation_data=(X_lc_test, y_lc_test), callbacks=[early_stopping])

# Plot the training loss and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Predictions on test data
y_pred_lc = model_lc.predict(X_lc_test)

# Evaluate the model (mean squared error or other metrics can be used)
mse = model_lc.evaluate(X_lc_test, y_lc_test)
print(f'Mean Squared Error on Test Data: {mse}')

def accuracy_metric(y_true, y_pred, threshold=0.05):
    return np.mean(np.abs(y_true - y_pred) < threshold)

# Assuming y_lc_test and y_pred are already scaled, calculate accuracy within a 5% threshold
accuracy = accuracy_metric(y_lc_test, y_pred_lc, threshold=0.10)  # 10% threshold
print(f'Custom Accuracy with 10% threshold: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/100
# /Users/somyasrivastava/Documents/Projects/Red-y-Set-Go---Menstrual-Cycle-Tracker/venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.1403 - val_loss: 0.0720
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0968 - val_loss: 0.0329
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0415 - val_loss: 0.0021
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0125 - val_loss: 0.0045
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0069 - val_loss: 0.0046
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0079 - val_loss: 0.0020
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0016 - val_loss: 4.8918e-04
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.4201e-04 - val_loss: 2.4038e-04
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.0992e-04 - val_loss: 4.3597e-04
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.6919e-04 - val_loss: 1.1388e-04
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.5592e-04 - val_loss: 4.2209e-04
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1401e-04 - val_loss: 1.0049e-04
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.8668e-04 - val_loss: 1.7245e-04
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3624e-04 - val_loss: 7.5730e-05
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0645e-04 - val_loss: 6.9048e-05
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2032e-04 - val_loss: 5.7856e-05
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 7.3725e-05 - val_loss: 5.4565e-05
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.5559e-05 - val_loss: 4.8056e-05
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.8049e-05 - val_loss: 3.7041e-05
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.7693e-05 - val_loss: 4.4374e-05
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.2456e-05 - val_loss: 4.1349e-05
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.9722e-05 - val_loss: 4.1844e-05
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.4353e-05 - val_loss: 3.8891e-05
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.7580e-05 - val_loss: 5.1884e-05
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.2647e-05 - val_loss: 4.7716e-05
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.2925e-05 - val_loss: 6.2934e-05
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.0727e-05 - val_loss: 4.2999e-05
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.8480e-05 - val_loss: 3.7782e-05
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.6448e-05 - val_loss: 3.3185e-05
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.1875e-05 - val_loss: 3.3475e-05
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.4864e-05 - val_loss: 3.4205e-05
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.8323e-05 - val_loss: 3.3285e-05
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.2605e-05 - val_loss: 3.2297e-05
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.7934e-05 - val_loss: 3.3643e-05
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.5720e-05 - val_loss: 3.2317e-05
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.1481e-05 - val_loss: 3.1577e-05
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.6189e-05 - val_loss: 4.3648e-05
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.7242e-05 - val_loss: 3.9757e-05
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.7802e-05 - val_loss: 4.2240e-05
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.1250e-05 - val_loss: 3.2221e-05
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0490e-05 - val_loss: 3.2824e-05
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.0855e-05 - val_loss: 3.0157e-05
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.7387e-05 - val_loss: 3.0268e-05
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.5892e-05 - val_loss: 3.0870e-05
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.1303e-05 - val_loss: 3.1624e-05
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.0742e-05 - val_loss: 2.9565e-05
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.3933e-05 - val_loss: 2.9491e-05
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.7969e-05 - val_loss: 2.9507e-05
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.4033e-05 - val_loss: 3.3464e-05
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.1770e-05 - val_loss: 2.9126e-05
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.6087e-05 - val_loss: 3.1667e-05
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.5361e-05 - val_loss: 2.9250e-05
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0117e-05 - val_loss: 3.4660e-05
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.1121e-05 - val_loss: 3.0212e-05
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.7603e-05 - val_loss: 2.9307e-05
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5429e-05 - val_loss: 2.8714e-05
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.6525e-05 - val_loss: 3.0217e-05
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.8917e-05 - val_loss: 2.8885e-05
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1167e-05 - val_loss: 3.0427e-05
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.9731e-05 - val_loss: 2.9781e-05
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.7384e-05 - val_loss: 2.8689e-05
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.4001e-05 - val_loss: 2.9540e-05
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.8703e-05 - val_loss: 2.9021e-05
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.4952e-05 - val_loss: 2.7162e-05
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.9622e-05 - val_loss: 2.7500e-05
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.8651e-06 - val_loss: 2.7842e-05
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.4456e-05 - val_loss: 3.0703e-05
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.9093e-05 - val_loss: 2.6775e-05
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0770e-05 - val_loss: 2.6692e-05
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.6010e-05 - val_loss: 2.7258e-05
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.7028e-05 - val_loss: 2.7065e-05
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.1629e-05 - val_loss: 2.7172e-05
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.3056e-05 - val_loss: 2.7358e-05
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.1963e-05 - val_loss: 2.7383e-05
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.5713e-05 - val_loss: 2.6106e-05
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.1423e-05 - val_loss: 2.7862e-05
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3477e-05 - val_loss: 2.5553e-05
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.7617e-05 - val_loss: 3.1580e-05
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5943e-05 - val_loss: 3.1357e-05
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0909e-05 - val_loss: 3.2582e-05
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3784e-05 - val_loss: 2.5563e-05
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0355e-05 - val_loss: 2.9703e-05
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0940e-05 - val_loss: 3.3574e-05
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1999e-05 - val_loss: 2.6265e-05
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1472e-05 - val_loss: 2.8452e-05
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.6397e-05 - val_loss: 2.7974e-05
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3813e-05 - val_loss: 2.4960e-05
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.7019e-05 - val_loss: 2.6091e-05
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.6815e-05 - val_loss: 2.7588e-05
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.6547e-05 - val_loss: 2.4656e-05
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.1597e-05 - val_loss: 2.8575e-05
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.9060e-05 - val_loss: 2.5885e-05
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5340e-05 - val_loss: 2.4588e-05
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.7064e-05 - val_loss: 2.5582e-05
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1828e-05 - val_loss: 2.4992e-05
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.4483e-05 - val_loss: 2.9301e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4588e-05
# Mean Squared Error on Test Data: 2.4588465748820454e-05
# Custom Accuracy with 10% threshold: 40.14%

# %%
def predict_next_cycle(model, user_input_data, scaler, num_features=45):

    # Creating a dummy array
    full_input_array = np.full((num_features,), np.mean(user_input_data))

    # Fill the known cycle length values at the start of the array
    full_input_array[:len(user_input_data)] = user_input_data

    # Scale the full input array using the same scaler
    full_input_array_scaled = scaler.transform(full_input_array.reshape(1, -1))

    # Reshape for LSTM input
    user_input_data_scaled = full_input_array_scaled.reshape((1, num_features, 1))  # 1 sample, timesteps, 1 feature

    # Predict the next cycle length (scaled)
    predicted_scaled = model.predict(user_input_data_scaled)

    # Unscale only the relevant cycle feature (assuming the prediction corresponds to the cycle length)
    cycle_length_column_index = 0  # Assuming the first column corresponds to the cycle length
    predicted_unscaled = (predicted_scaled * (scaler.data_max_[cycle_length_column_index] - scaler.data_min_[cycle_length_column_index])
                          + scaler.data_min_[cycle_length_column_index])

    return predicted_unscaled.flatten()[0]


# Example usage:

# Assume you have the following user input data (previous cycle lengths)
user_input_data = [29, 30, 28, 31]  # Replace this with actual user input

# Make the prediction
predicted_next_cycle_length = predict_next_cycle(model_lc, user_input_data, cycle_length_scaler)

# Output the predicted cycle length
print(f"Predicted next cycle length: {predicted_next_cycle_length}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Predicted next cycle length: 32.27937698364258

# %%
model_lc.save('../model/model_lc.keras')

# %%
# !pip install django
# Out:
# Requirement already satisfied: django in /Users/somyasrivastava/Documents/Projects/Red-y-Set-Go---Menstrual-Cycle-Tracker/venv/lib/python3.12/site-packages (5.1.2)
# Requirement already satisfied: asgiref<4,>=3.8.1 in /Users/somyasrivastava/Documents/Projects/Red-y-Set-Go---Menstrual-Cycle-Tracker/venv/lib/python3.12/site-packages (from django) (3.8.1)
# Requirement already satisfied: sqlparse>=0.3.1 in /Users/somyasrivastava/Documents/Projects/Red-y-Set-Go---Menstrual-Cycle-Tracker/venv/lib/python3.12/site-packages (from django) (0.5.1)

# %%
import os
import sys
import django

# Add the parent directory to the Python path if the notebook is in the same directory as settings.py
sys.path.append(os.path.dirname(os.path.abspath('')))  # Adds the current working directory to the system path

# Set DJANGO_SETTINGS_MODULE environment variable
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'tracker.settings')  # Use the correct module path

# Set up Django
django.setup()

# %%
from asgiref.sync import sync_to_async
from home.models import UserCycleData

async def get_user_data():
    # Fetch all UserCycleData entries asynchronously
    user_data = await sync_to_async(list)(UserCycleData.objects.all())

    # Ensure that accessing related fields like 'user' is also done asynchronously
    for data in user_data:
        data.user = await sync_to_async(lambda: data.user)()  # Access 'user' asynchronously

    return user_data

# Fetch the data in an asynchronous context
user_data = await get_user_data()
print(user_data)
# Out:
# [<UserCycleData: yamos123's Cycle Data - Age: 20>, <UserCycleData: yamos123's Cycle Data - Age: 20>]

# %%
from asgiref.sync import sync_to_async
import pandas as pd
from home.models import UserCycleData

async def extract_user_features():
    # Fetch user data asynchronously
    user_data = await sync_to_async(list)(UserCycleData.objects.all())

    features = []
    for data in user_data:
        # Access the user field asynchronously
        user_id = await sync_to_async(lambda: data.user.id)()  # Fetch user ID asynchronously

        feature_row = {
            'user_id': user_id,  # Using user_id instead of the related user object
            'cramp_level': data.cramp_level,
            'current_date': data.current_date,
            'height': data.height,
            'weight': data.weight,
            'age': data.age,
            'previous_cycle_start': data.previous_cycle_start,
            'previous_cycle_end': data.previous_cycle_end,  # Ensure this field exists
        }
        features.append(feature_row)

    # Convert the list of dictionaries to a DataFrame (optional)
    df = pd.DataFrame(features)
    return df

# Call the function asynchronously
user_features = await extract_user_features()
print(user_features)
# Out:
#    user_id  cramp_level current_date  height  weight  age  \
# 0        1            5   2024-10-15   170.0      54   20
# 1        1            5   2024-10-17   170.0      54   20
#
#   previous_cycle_start previous_cycle_end
# 0           2024-10-10         2024-11-07
# 1           2024-10-16         2024-11-12

# %%
print(user_features.columns)
# Out:
# Index(['user_id', 'cramp_level', 'current_date', 'height', 'weight', 'age',
#        'previous_cycle_start', 'previous_cycle_end'],
#       dtype='object')

# %%
predicting_df = user_features[['current_date', 'previous_cycle_start', 'previous_cycle_end']]
print(type(predicting_df['previous_cycle_start']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Convert 'previous_cycle_start' and 'previous_cycle_end' to datetime
user_features['previous_cycle_start'] = pd.to_datetime(user_features['previous_cycle_start'])
user_features['previous_cycle_end'] = pd.to_datetime(user_features['previous_cycle_end'])

# Extract the start dates as a NumPy array
start_dates = user_features['previous_cycle_start'].values

# Calculate cycle lengths in days
cycle_lengths = (user_features['previous_cycle_end'] - user_features['previous_cycle_start']).dt.days

# Convert to array and list as needed
start_dates_array = np.array(start_dates)
cycle_lengths_list = cycle_lengths.tolist()

# Display the results
print("Start Dates Array:", start_dates_array)
print("Cycle Lengths List:", cycle_lengths_list)
# Out:
# Start Dates Array: ['2024-10-10T00:00:00.000000000' '2024-10-16T00:00:00.000000000']
# Cycle Lengths List: [28, 27]

# %%
predicted_next_cycle_length = predict_next_cycle(model_lc, cycle_lengths_list, cycle_length_scaler)
print(predicted_next_cycle_length)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 29.313183

# %%
from datetime import timedelta

# Ensure the array is of datetime dtype
start_dates_array = pd.to_datetime(start_dates_array)

# Predicted cycle length
days_needed = int(round(predicted_next_cycle_length))  

# Add the timedelta
next_cycle_date = start_dates_array[-1] + timedelta(days=days_needed)

print("Next cycle date:", next_cycle_date)
# Out:
# Next cycle date: 2024-11-14 00:00:00

# %%
data = {
    'User ID': [user_features['user_id']],  # Replace with actual data
    'Predicted Cycle Length (days)': [predicted_next_cycle_length],
    'Predicted Next Cycle Start': [next_cycle_date]
}

df = pd.DataFrame(data)

df.to_csv('predicted_cycle_data.csv', index=False)

print("Predicted values saved to predicted_cycle_data.csv")
# Out:
# Predicted values saved to predicted_cycle_data.csv

# %%
data = {
    'User ID': [user_features['user_id'][0]],  
    'Predicted Cycle Length (days)': [predicted_next_cycle_length],
    'Last Cycle Date': [start_dates_array[-1]],
    'Predicted Next Cycle Start': [next_cycle_date]
}

df = pd.DataFrame(data)

# Save to CSV
df.to_csv('predicted_cycle_data.csv', index=False)

print("Corrected predicted values saved to predicted_cycle_data.csv")
# Out:
# Corrected predicted values saved to predicted_cycle_data.csv

# %%
df_output = pd.read_csv('predicted_cycle_data.csv')
print(df_output)
# Out:
#    User ID  Predicted Cycle Length (days) Predicted Next Cycle Start
# 0        1                      29.313183                 2024-11-14
